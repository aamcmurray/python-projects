# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import math
import scipy.stats as stats
import sys

SMALL_SIZE=10
MEDIUM_SIZE=15
BIGGER_SIZE=20
BIGGEST_SIZE=25

plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGEST_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=BIGGER_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=MEDIUM_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title

data = pd.read_csv("D:/Shared by Pankaj/OneDrive_2020-08-13/August 2019 Light sheet/Ki67/kicycle2d.csv")
secondarydata = pd.read_csv("D:/Shared by Pankaj/OneDrive_2020-08-13/August 2019 Light sheet/Ki67/kicycleagg2d.csv")

# %%
y=[]
for key in list(data.keys()):
    y.append(np.array(data[key][:]))
x=[]
for key in list(data.keys()):
    x.append(key)
    
yy=[]
for key in list(secondarydata.keys()):
    yy.append(np.array(secondarydata[key][:]))
xx=[]
for key in list(secondarydata.keys()):
    xx.append(key)
# Out:
# (['cell', 'time', 'g1', 's', 'g2', 'g1err', 'serr', 'g2err'],
#  [array(['c1', 's5', 's6', 's7', 's8', 'c2', 's9', 's10', 's11', 's12'],
#         dtype=object),
#   array([24, 24, 24, 24, 24, 48, 48, 48, 48, 48], dtype=int64),
#   array([39.54154728, 35.31939163, 34.79365079, 33.79552716, 33.31939163,
#          30.54154728, 37.31939163, 38.79365079, 35.79552716, 36.63157895]),
#   array([43.83954155, 50.75285171, 52.28571429, 50.10543131, 51.75285171,
#          48.83954155, 48.75285171, 49.28571429, 46.10543131, 50.0877193 ]),
#   array([16.61891117, 13.92775665, 12.92063492, 16.09904153, 14.92775665,
#          20.61891117, 13.92775665, 11.92063492, 18.09904153, 13.28070175]),
#   array([1.50610905, 1.49265612, 1.64111755, 1.46647563, 1.49265612,
#          1.50610905, 1.49265612, 1.64111755, 1.46647563, 1.53252276]),
#   array([1.56813539, 3.8766498 , 3.55437298, 2.38729194, 3.8766498 ,
#          1.56813539, 3.8766498 , 3.55437298, 2.38729194, 3.10223747]),
# ...

# %%
N = 10
g1means = y[2]
smeans = y[3]
g2means = y[4]

g1std = y[5]
sstd = y[6]
g2std = y[7]

M=4
sec_g1means = yy[2]
sec_smeans = yy[3]
sec_g2means = yy[4]

sec_g1std = yy[5]
sec_sstd = yy[6]
sec_g2std = yy[7]

# %%
fig=plt.figure(figsize=(22,12))
colors=['#142850','#27496D','#0C7B93','#00A8CC']

ind = np.arange(N)    # the x locations for the groups
width = 0.35       # the width of the bars: can also be len(x) sequence

p1 = plt.bar(ind, g1means, width=0.5, yerr=g1std,color=colors[0])
p2 = plt.bar(ind, smeans, width=0.5,
             bottom=g1means, yerr=sstd,color=colors[1] )
p3 = plt.bar(ind, g2means,bottom=np.array(smeans)+np.array(g1means), width=0.5, yerr=g2std,color=colors[2])

plt.ylabel('Average %')
plt.title('Ki67 Cell Cycle Progression')
plt.xticks(ind, ('control 24h', 's1 24h', 's2 24h', 's3 24h', 's4 24h', 'control 48h', 's1 48h', 's2 48h', 's3 48h', 's4 48h',
         's5 48h'))
plt.yticks(np.arange(0, 101, 10))
plt.legend((p1[0], p2[0],p3[0]), ('G1', 'S','G2'), fontsize=25, loc=8, ncol=3)

plt.show()
